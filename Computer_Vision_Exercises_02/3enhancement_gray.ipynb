# %%
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
from scipy.misc import imread

# %%
# The most basic transformation function is the identity function, which simply maps each pixel value
# to the same value. Look at the identity transformation function.

x = np.uint8(np.arange(256));
plt.plot(x)
plt.show()

# Use the transformation function on the moon image to see how the identity function works.

I = imread('imgs\moon.tif');
I_adj = x[I];

plt.subplot(1,2,1)
plt.imshow(I,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(I_adj,cmap='gray')
plt.show()

# How can we show that the adjusted image and the original image are equivalent?


# 2. Create a negative transformation function

# %%
# Logarithmic transformation functions can be used to compress the dynamic range of an image in
# order to bring out features that were not originally as clear.
# Generate a logarithmic transformation function.
# Use the transformation function to generate the adjusted image of drill.tif

# 1


# 2

# %%
# Generate a gamma transformation function.
# Use the transformation function to generate the adjusted image of drill.tif
# How does the shape of the curve change if we were to use a different value for gamma?


# 1


# 2


# 3
